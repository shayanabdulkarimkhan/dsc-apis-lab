# %% [markdown]
# # APIs - Cumulative Lab
#
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API.
#
# ## Objectives
#
# You will be able to:
#
# * Practice using functions to organize your code
# * Use pagination to retrieve all results from an API query
# * Practice parsing data returned from an API query
# * Practice interpreting visualizations of a dataset
# * Create maps using Folium

# %% [markdown]
# ## Your Task: Query Yelp for All Businesses in a Category and Analyze the Results
#
# ![restaurant counter with pizza](images/restaurant_counter.jpg)
#
# Photo by <a href="https://unsplash.com/@jordanmadrid?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Jordan Madrid</a> on <a href="/s/photos/pizza-restaurant?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Overview
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. In this lab, you will write a query of businesses on Yelp, then use *pagination* to retrieve all possible results for that query. Then you will create a summary of your findings, including a Folium map of the geographic locations of those businesses.
#
# ### Technical Details
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the **API limits**. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a **maximum of 50 results per request** and defaults to 20. Furthermore, any search will be limited to a **total of 1000 results**. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# Also, be mindful of the **API** ***rate*** **limits**. You can only make **5000 requests per day** and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use `time.sleep(n)` to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a list of dictionaries (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ### Requirements
#
# #### 1. Make the Initial Request
#
# Start by filling in your API key to make the initial request to the business search API. Investigate the structure of the response you get back and start figuring out how you will extract the relevant information.
#
# #### 2. Add Pagination
#
# Using loops and functions, collect the maximum number of results for your query from the API.
#
# #### 3. Perform Exploratory Analysis
#
# Interpret visualizations related to the price range, average rating, and number of reviews for all query results.
#
# #### 4. Create a Folium Map
#
# Using latitude and longitude data, plot the query results on an interactive map.

# %% [markdown]
# ## 1. Make the Initial Request
#
# ### Querying
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.
#
# Use the `requests` library ([documentation here](https://requests.readthedocs.io/en/master/user/quickstart/#make-a-request)).
#
# You'll also need an API key from Yelp. If you haven't done this already, go to the Yelp [Manage App page](https://www.yelp.com/developers/v3/manage_app) and create a new app (after making an account if you haven't already).

# %%
# Replace None with appropriate code

# Import the requests library
import requests
import json

def get_keys(path):
    with open(path) as f:
        return json.load(f)

# Get this from the "Manage App" page. Make sure you set them
# back to None before pushing this to GitHub, since otherwise
# your credentials will be compromised
keys = get_keys("/Users/shaya/.secret/yelp_api.json")
api_key = keys['api_key']

# These can be whatever you want! But the solution uses "pizza"
# and "New York NY" if you want to compare your work directly
term = "pizza"
location = "New York NY"

# Set up params for request
url = "https://api.yelp.com/v3/businesses/search"
headers = {
    "Authorization": "Bearer {}".format(api_key)
}
url_params = {
    "term": term.replace(" ", "+"),
    "location": location.replace(" ", "+")
}

# Make the request using requests.get, passing in
# url, headers=headers, and params=url_params
response = requests.get(url, headers = headers, params = url_params)

# Confirm we got a 200 response
response
# Out:
# <Response [200]>

# %%
# Run this cell without changes

# Get the response body in JSON format
response_json = response.json()
# View the keys
response_json.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# ### Extracting Data
#
# Now, retrieve the value associated with the `'businesses'` key, and inspect its contents.

# %%
# Replace None with appropriate code

# Retrieve the value from response_json
businesses = response_json['businesses']

# View the first 2 records
b = businesses[:2]
b
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HVjttLctuIzKL3LSlsRf-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=-2XOoBwybOjdFvvbvTNC4A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-2XOoBwybOjdFvvbvTNC4A',
#   'review_count': 4438,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 1961.8771417367063},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j6Hoc_YpJJapUUzfd9pj8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=-2XOoBwybOjdFvvbvTNC4A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=-2XOoBwybOjdFvvbvTNC4A',
#   'review_count': 2496,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 308.56984360837544}]

# %% [markdown]
# ### Preparing Data
#
# Write a function `prepare_data` that takes in a list of dictionaries like `businesses` and returns a copy that has been prepared for analysis:
#
# 1. The `coordinates` key-value pair has been converted into two separate key-value pairs, `latitude` and `longitude`
# 2. All other key-value pairs except for `name`, `review_count`, `rating`, and `price` have been dropped
# 3. All dictionaries missing one of the relevant keys or containing null values have been dropped
#
# In other words, the final keys for each dictionary should be `name`, `review_count`, `rating`, `price`, `latitude`, and `longitude`.
#
# Complete the function in the cell below:

# %%
i=0
for value in b[0]:
    print(value)
# Out:
# id
# alias
# name
# image_url
# is_closed
# url
# review_count
# categories
# rating
# coordinates
# transactions
# price
# location
# phone
# display_phone
# distance

# %%
# Replace None with appropriate code

def prepare_data(data_list):
    """
    This function takes in a list of dictionaries and prepares it
    for analysis
    """
    
    # Make a new list to hold results
    results = []
    
    for business_data in data_list:
    
        # Make a new dictionary to hold prepared data for this business
        prepared_data = {'name': None,'review_count': None, 'rating': None, 'price': None, 'latitude': None, 'longitude': None}
        
        # Extract name, review_count, rating, and price key-value pairs
        # from business_data and add to prepared_data
        # If a key is not present in business_data, add it to prepared_data
        # with an associated value of None
        
#         prepared_data['name'] = business_data['name']
#         prepared_data['review_count'] = business_data['review_count']
#         prepared_data['rating'] = business_data['rating']
#         prepared_data['price'] = business_data['price']
        
        for key in business_data:
            if key in ['name', 'review_count', 'rating', 'price']:
                prepared_data[key] = business_data[key]
                               
    
        # Parse and add latitude and longitude columns
        if business_data['coordinates'] is not None:
            prepared_data['latitude'] = business_data['coordinates']['latitude']
            prepared_data['longitude'] = business_data['coordinates']['longitude']
        else:
            prepared_data['latitude'] = []
            prepared_data['longitude'] = []
            
        
        # Add to list if all values are present
        if all(prepared_data.values()):
            results.append(prepared_data)
    
    return results
    
# Test out function
prepared_businesses = prepare_data(businesses)
prepared_businesses
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4438,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2496,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6368,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 734,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': 'Lucali',
#   'review_count': 1833,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.681840746711224,
#   'longitude': -74.0003327},
#  {'name': 'Rubirosa',
#   'review_count': 2736,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "Joe's Pizza",
#   'review_count': 2850,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73060076,
#   'longitude': -74.00215997},
#  {'name': "Joe's Pizza",
#   'review_count': 1575,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7547,
#   'longitude': -73.98696},
#  {'name': "John's of Bleecker Street",
#   'review_count': 2333,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73158,
#   'longitude': -74.00332},
#  {'name': "Roberta's",
#   'review_count': 3137,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70493,
#   'longitude': -73.93399},
#  {'name': 'Bleecker Street Pizza',
#   'review_count': 2654,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7320627016512,
#   'longitude': -74.0036552270137},
#  {'name': "Grimaldi's Pizzeria",
#   'review_count': 4833,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7026459,
#   'longitude': -73.9932413},
#  {'name': "Joe's Pizza",
#   'review_count': 1001,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73331,
#   'longitude': -73.98763},
#  {'name': "Paulie Gee's",
#   'review_count': 1318,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729546,
#   'longitude': -73.958568},
#  {'name': "Luigi's Pizzeria",
#   'review_count': 272,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6897,
#   'longitude': -73.965369},
#  {'name': "Scarr's Pizza",
#   'review_count': 596,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71534,
#   'longitude': -73.9914},
#  {'name': 'Stone Bridge Pizza & Salad',
#   'review_count': 303,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75225,
#   'longitude': -73.98061},
#  {'name': 'Di Fara Pizza',
#   'review_count': 3810,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.625093,
#   'longitude': -73.961531},
#  {'name': 'Piz-zetta',
#   'review_count': 314,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69116658201196,
#   'longitude': -73.99065911521895},
#  {'name': "Luigi's Pizza",
#   'review_count': 411,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.66163,
#   'longitude': -73.99334},
#  {'name': 'Olio e Più',
#   'review_count': 3467,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.733798036104304,
#   'longitude': -73.99977392649927},
#  {'name': 'East Village Pizza',
#   'review_count': 435,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.728199,
#   'longitude': -73.985182},
#  {'name': 'Village Square Pizza',
#   'review_count': 234,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72748,
#   'longitude': -73.98268},
#  {'name': 'Made In New York Pizza',
#   'review_count': 434,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.783841,
#   'longitude': -73.977569},
#  {'name': "Dellarocco's",
#   'review_count': 321,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6950309,
#   'longitude': -73.9961252},
#  {'name': "Joe's Pizza",
#   'review_count': 406,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7168952,
#   'longitude': -73.95892996733771},
#  {'name': 'Sottocasa Pizzeria',
#   'review_count': 681,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.688285,
#   'longitude': -73.989006},
#  {'name': "Paulie Gee's Slice Shop",
#   'review_count': 286,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72836,
#   'longitude': -73.9572},
#  {'name': "Lil Frankie's",
#   'review_count': 1354,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723625,
#   'longitude': -73.988555},
#  {'name': "Joe's Pizza",
#   'review_count': 358,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7101297729083,
#   'longitude': -74.0077206864953},
#  {'name': 'Goodfellas Pizzeria of LIC',
#   'review_count': 74,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75334,
#   'longitude': -73.93716},
#  {'name': 'SIMÒ PIZZA',
#   'review_count': 220,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187},
#  {'name': 'Unregular Pizza',
#   'review_count': 123,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73398,
#   'longitude': -73.98961},
#  {'name': 'Il Porto Ristorante & Wood Fired Pizza',
#   'review_count': 364,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6974427,
#   'longitude': -73.9675197},
#  {'name': 'Song E Napule',
#   'review_count': 622,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': 'NY Pizza Suprema',
#   'review_count': 2290,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7502059936523,
#   'longitude': -73.9953231811523},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 4101,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7321124557704,
#   'longitude': -73.9839056828882},
#  {'name': 'IL Brigante',
#   'review_count': 463,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.707492,
#   'longitude': -74.002571},
#  {'name': "Philomena's",
#   'review_count': 150,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7432,
#   'longitude': -73.92275},
#  {'name': 'Marinara Pizza',
#   'review_count': 308,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7826,
#   'longitude': -73.95351},
#  {'name': 'Front Street Pizza',
#   'review_count': 422,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70244,
#   'longitude': -73.98943},
#  {'name': "Ace's Pizza",
#   'review_count': 98,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71505,
#   'longitude': -73.958365}]

# %% [markdown]
# Check that your function created the correct keys:

# %%
# Run this cell without changes

assert sorted(list(prepared_businesses[0].keys())) == ['latitude', 'longitude', 'name', 'price', 'rating', 'review_count']

# %% [markdown]
# The following code will differ depending on your query, but we expect there to be 20 businesses in the original list, and potentially fewer in the prepared list (if any of them were missing data):

# %%
# Run this cell without changes
print("Original:", len(businesses))
print("Prepared:", len(prepared_businesses))
# Out:
# Original: 50
# Prepared: 42

# %% [markdown]
# Great! We will reuse this function once we have retrieved the full dataset.

# %% [markdown]
# ## 2. Add Pagination
#
# Now that you are able to extract information from one page of the response, let's figure out how to request as many pages as possible.
#
# ### Determining the Total
#
# Depending on the number of total results for your query, you will either retrieve all of the results, or just the first 1000 (if there are more than 1000 total).
#
# We can find the total number of results using the `"total"` key:

# %%
# Run this cell without changes
response_json["total"]
# Out:
# 12100

# %% [markdown]
# (This is specific to the implementation of the Yelp API. Some APIs will just tell you that there are more pages, or will tell you the number of pages total, rather than the total number of results. If you're not sure, always check the documentation.)
#
# In the cell below, assign the variable `total` to either the value shown above (if it is less than 1000), or 1000.

# %%
# Replace None with appropriate code
total = 1000

# %% [markdown]
# ### Calculating the Offsets
#
# The documentation states in the parameters section:
#
# > **Name**: `limit`, **Type:** int, **Description:** Optional. Number of business results to return. By default, it will return 20. Maximum is 50.
#
# > **Name**: `offset`, **Type:** int, **Description:** Optional. Offset the list of returned business results by this amount.
#
# So, to get the most results with the fewest API calls we want to set a limit of 50 every time. If, say, we wanted to get 210 total results, that would mean:
#
# 1. Offset of `0` (first 50 records)
# 2. Offset of `50` (second 50 records)
# 3. Offset of `100` (third 50 records)
# 4. Offset of `150` (fourth 50 records)
# 5. Offset of `200` (final 10 records)
#
# In the cell below, create a function `get_offsets` that takes in a total and returns a list of offsets for that total. You can assume that there is a limit of 50 every time.
#
# *Hint: you can use `range` ([documentation here](https://docs.python.org/3.3/library/stdtypes.html?highlight=range#range)) to do this in one line of code. Just make the returned result is a list.*

# %%
# Replace None with appropriate code
def get_offsets(total):
    """
    Get a list of offsets needed to get all pages
    of data up until the total
    """
    return list(range(0,total,50))

# %% [markdown]
# Check that your function works below:

# %%
# Run this cell without changes

assert get_offsets(200) == [0, 50, 100, 150]
assert get_offsets(210) == [0, 50, 100, 150, 200]

# %% [markdown]
# ### Putting It All Together
#
# Recall that the following variable has already been declared for you:

# %%
# Run this cell without changes
url_params
# Out:
# {'term': 'pizza', 'location': 'New+York+NY', 'limit': 50, 'offset': 0}

# %% [markdown]
# We'll go ahead and also specify that the limit should be 50 every time:

# %%
# Run this cell without changes
url_params["limit"] = 50

# %% [markdown]
# In order to modify the offset, you'll need to add it to `url_params` with the key `"offset"` and whatever value is needed.
#
# In the cell below, write code that:
#
# * Creates an empty list for the full prepared dataset
# * Loops over all of the offsets from `get_offsets` and makes an API call each time with the specified offset
# * Calls `prepare_data` to get a cleaned version of the result of each API call
# * Extends the full prepared dataset list with each query's prepared dataset

# %%
# Replace None with appropriate code

# Create an empty list for the full prepared dataset
full_dataset = []

for offset in get_offsets(total):
    # Add or update the "offset" key-value pair in url_params
    url_params["offset"] = offset
    
    # Make the query and get the response
    response = requests.get(url, headers=headers, params=url_params)
    
    # Get the response body in JSON format
    response_json = response.json()
    
    # Get the list of businesses from the response_json
    businesses = response_json['businesses']
    
    # Call the prepare_data function to get a list of processed data
    prepared_businesses = prepare_data(businesses)
    
    # Extend full_dataset with this list (don't append, or you'll get
    # a list of lists instead of a flat list)
    full_dataset.extend(prepared_businesses)

# Check the length of the full dataset. It will be up to `total`,
# potentially less if there were missing values
len(full_dataset)
full_dataset
# Out:
# [{'name': 'Prince Street Pizza',
#   'review_count': 4438,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575},
#  {'name': "Juliana's",
#   'review_count': 2496,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397},
#  {'name': "Lombardi's Pizza",
#   'review_count': 6368,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561},
#  {'name': "L'industrie Pizzeria",
#   'review_count': 734,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71162,
#   'longitude': -73.95783},
#  {'name': 'Lucali',
#   'review_count': 1833,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.681840746711224,
#   'longitude': -74.0003327},
#  {'name': 'Rubirosa',
#   'review_count': 2736,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.722766,
#   'longitude': -73.996233},
#  {'name': "Joe's Pizza",
#   'review_count': 2850,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73060076,
#   'longitude': -74.00215997},
#  {'name': "Joe's Pizza",
#   'review_count': 1575,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7547,
#   'longitude': -73.98696},
#  {'name': "John's of Bleecker Street",
#   'review_count': 2333,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73158,
#   'longitude': -74.00332},
#  {'name': "Roberta's",
#   'review_count': 3137,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70493,
#   'longitude': -73.93399},
#  {'name': 'Bleecker Street Pizza',
#   'review_count': 2654,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7320627016512,
#   'longitude': -74.0036552270137},
#  {'name': "Grimaldi's Pizzeria",
#   'review_count': 4833,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7026459,
#   'longitude': -73.9932413},
#  {'name': "Joe's Pizza",
#   'review_count': 1001,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73331,
#   'longitude': -73.98763},
#  {'name': "Paulie Gee's",
#   'review_count': 1318,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729546,
#   'longitude': -73.958568},
#  {'name': "Luigi's Pizzeria",
#   'review_count': 272,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6897,
#   'longitude': -73.965369},
#  {'name': "Scarr's Pizza",
#   'review_count': 596,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71534,
#   'longitude': -73.9914},
#  {'name': 'Stone Bridge Pizza & Salad',
#   'review_count': 303,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75225,
#   'longitude': -73.98061},
#  {'name': 'Di Fara Pizza',
#   'review_count': 3810,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.625093,
#   'longitude': -73.961531},
#  {'name': 'Piz-zetta',
#   'review_count': 314,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69116658201196,
#   'longitude': -73.99065911521895},
#  {'name': "Luigi's Pizza",
#   'review_count': 411,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.66163,
#   'longitude': -73.99334},
#  {'name': 'Olio e Più',
#   'review_count': 3467,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.733798036104304,
#   'longitude': -73.99977392649927},
#  {'name': 'East Village Pizza',
#   'review_count': 435,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.728199,
#   'longitude': -73.985182},
#  {'name': 'Village Square Pizza',
#   'review_count': 234,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72748,
#   'longitude': -73.98268},
#  {'name': 'Made In New York Pizza',
#   'review_count': 434,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.783841,
#   'longitude': -73.977569},
#  {'name': "Dellarocco's",
#   'review_count': 321,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6950309,
#   'longitude': -73.9961252},
#  {'name': "Joe's Pizza",
#   'review_count': 406,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7168952,
#   'longitude': -73.95892996733771},
#  {'name': 'Sottocasa Pizzeria',
#   'review_count': 681,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.688285,
#   'longitude': -73.989006},
#  {'name': "Paulie Gee's Slice Shop",
#   'review_count': 286,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72836,
#   'longitude': -73.9572},
#  {'name': "Lil Frankie's",
#   'review_count': 1354,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723625,
#   'longitude': -73.988555},
#  {'name': "Joe's Pizza",
#   'review_count': 358,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7101297729083,
#   'longitude': -74.0077206864953},
#  {'name': 'Goodfellas Pizzeria of LIC',
#   'review_count': 74,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75334,
#   'longitude': -73.93716},
#  {'name': 'SIMÒ PIZZA',
#   'review_count': 220,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187},
#  {'name': 'Unregular Pizza',
#   'review_count': 123,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.73398,
#   'longitude': -73.98961},
#  {'name': 'Song E Napule',
#   'review_count': 622,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72813,
#   'longitude': -74.00188},
#  {'name': 'NY Pizza Suprema',
#   'review_count': 2290,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7502059936523,
#   'longitude': -73.9953231811523},
#  {'name': 'Il Porto Ristorante & Wood Fired Pizza',
#   'review_count': 364,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6974427,
#   'longitude': -73.9675197},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 4101,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7321124557704,
#   'longitude': -73.9839056828882},
#  {'name': 'IL Brigante',
#   'review_count': 463,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.707492,
#   'longitude': -74.002571},
#  {'name': "Philomena's",
#   'review_count': 150,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7432,
#   'longitude': -73.92275},
#  {'name': 'Marinara Pizza',
#   'review_count': 308,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7826,
#   'longitude': -73.95351},
#  {'name': 'Front Street Pizza',
#   'review_count': 422,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70244,
#   'longitude': -73.98943},
#  {'name': "Ace's Pizza",
#   'review_count': 98,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71505,
#   'longitude': -73.958365},
#  {'name': "Giuseppina's",
#   'review_count': 343,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6603430973463,
#   'longitude': -73.9907741546631},
#  {'name': 'Norma',
#   'review_count': 543,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743553,
#   'longitude': -73.980026},
#  {'name': "Arturo's",
#   'review_count': 732,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7273563342024,
#   'longitude': -74.0004944801331},
#  {'name': 'L & B Spumoni Gardens',
#   'review_count': 4298,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.594715,
#   'longitude': -73.981316},
#  {'name': 'Nolita Pizza',
#   'review_count': 149,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7208883,
#   'longitude': -73.9962404},
#  {'name': 'Ribalta Pizza',
#   'review_count': 680,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7334346,
#   'longitude': -73.9916923},
#  {'name': "Lombardo's of Bay Ridge",
#   'review_count': 178,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.634741,
#   'longitude': -74.0284259},
#  {'name': 'Da Andrea',
#   'review_count': 1468,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.736218,
#   'longitude': -73.99597},
#  {'name': 'La Nonna Krispy Krust Pizza',
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.717953,
#   'longitude': -73.9637027},
#  {'name': 'Luna Pizza',
#   'review_count': 95,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.713245675315,
#   'longitude': -73.998651104496},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 628,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76458,
#   'longitude': -73.98247},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 589,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6818695,
#   'longitude': -73.976181},
#  {'name': "Rosa's Pizza",
#   'review_count': 168,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7139499,
#   'longitude': -73.95563},
#  {'name': 'My Pie Pizzeria Romana',
#   'review_count': 850,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7608512,
#   'longitude': -73.9694809},
#  {'name': 'Fornino',
#   'review_count': 280,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.692930215177675,
#   'longitude': -74.00165153160219},
#  {'name': 'Brunetti Pizza',
#   'review_count': 333,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73829,
#   'longitude': -74.0054},
#  {'name': 'Gelso & Grand',
#   'review_count': 1254,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71958,
#   'longitude': -73.99734},
#  {'name': "Ignazio's",
#   'review_count': 577,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.703137,
#   'longitude': -73.993608},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 895,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.797157,
#   'longitude': -73.93488},
#  {'name': 'Il Mattone',
#   'review_count': 100,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.720799,
#   'longitude': -74.0091255},
#  {'name': 'Emily - West Village',
#   'review_count': 864,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.729375015649076,
#   'longitude': -74.00386306706551},
#  {'name': 'Siena Pizza & Cannoli',
#   'review_count': 68,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.708152,
#   'longitude': -74.013864},
#  {'name': 'Saraghina Pizzeria',
#   'review_count': 968,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6837407,
#   'longitude': -73.9353473},
#  {'name': 'Barboncino Pizza & Bar',
#   'review_count': 1069,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.67206,
#   'longitude': -73.95717},
#  {'name': 'Time Out Market New York',
#   'review_count': 382,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70342863348067,
#   'longitude': -73.99214637055226},
#  {'name': "Adrienne's Pizzabar",
#   'review_count': 1774,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7043362,
#   'longitude': -74.0101733},
#  {'name': 'Champion Pizza',
#   'review_count': 392,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7215270996094,
#   'longitude': -73.9970855712891},
#  {'name': "Vinnie's Pizzeria",
#   'review_count': 720,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7189,
#   'longitude': -73.956843},
#  {'name': '&pizza - Astor Place',
#   'review_count': 202,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.729798,
#   'longitude': -73.9926904},
#  {'name': 'Krispy Pizza ',
#   'review_count': 300,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62236,
#   'longitude': -74.0055},
#  {'name': 'Famous Calabria',
#   'review_count': 95,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.711942,
#   'longitude': -73.999349},
#  {'name': 'Marinara Pizza',
#   'review_count': 17,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72981,
#   'longitude': -73.98658},
#  {'name': 'Sottocasa Pizzeria - Harlem',
#   'review_count': 322,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.8055499,
#   'longitude': -73.94746},
#  {'name': 'Lo Duca Pizza',
#   'review_count': 139,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6349400235262,
#   'longitude': -73.9625812061059},
#  {'name': 'Montesacro Pinseria Brooklyn',
#   'review_count': 201,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71338,
#   'longitude': -73.95136},
#  {'name': "Graziella's",
#   'review_count': 471,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6904563903809,
#   'longitude': -73.9696273803711},
#  {'name': 'Marta',
#   'review_count': 943,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7445882,
#   'longitude': -73.9847936},
#  {'name': 'B Side Pizza & Wine Bar',
#   'review_count': 1229,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76388,
#   'longitude': -73.98821},
#  {'name': "Brooklyn's Homeslice Pizzeria",
#   'review_count': 180,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.680702,
#   'longitude': -73.967455},
#  {'name': 'Emily',
#   'review_count': 875,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68351,
#   'longitude': -73.96643},
#  {'name': 'Sofia Pizza Shoppe',
#   'review_count': 239,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75674,
#   'longitude': -73.96431},
#  {'name': "MAMA'S TOO!",
#   'review_count': 552,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.80084,
#   'longitude': -73.96766},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 248,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72892,
#   'longitude': -73.98411},
#  {'name': "Patrizia's Pizza and Pasta",
#   'review_count': 718,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7398415,
#   'longitude': -73.9792862},
#  {'name': 'Ops',
#   'review_count': 170,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70276,
#   'longitude': -73.9171},
#  {'name': "Sicily's Best Pizzeria",
#   'review_count': 87,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.70517,
#   'longitude': -73.915155},
#  {'name': 'Lions & Tigers & Squares Detroit Pizza',
#   'review_count': 514,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74506,
#   'longitude': -73.99834},
#  {'name': 'Paesano of Mulberry Street',
#   'review_count': 1226,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.718554,
#   'longitude': -73.997447},
#  {'name': 'Barano',
#   'review_count': 297,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.710372,
#   'longitude': -73.96794},
#  {'name': 'GRUPPO NYCThinCrust Pizza',
#   'review_count': 266,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72474,
#   'longitude': -73.98161},
#  {'name': 'Emmy Squared Pizza: East Village - New York',
#   'review_count': 332,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72598,
#   'longitude': -73.98672},
#  {'name': 'Speedy Romeo',
#   'review_count': 647,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6875154792236,
#   'longitude': -73.959874469611},
#  {'name': "Fazio's",
#   'review_count': 195,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.69442,
#   'longitude': -73.91039},
#  {'name': 'Leo',
#   'review_count': 60,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7125608,
#   'longitude': -73.9567886},
#  {'name': 'Baci & Abbracci',
#   'review_count': 338,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7139015197754,
#   'longitude': -73.96044921875},
#  {'name': "Mike's Pizza",
#   'review_count': 140,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75214,
#   'longitude': -73.934339},
#  {'name': 'Underground Pizza',
#   'review_count': 316,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70499,
#   'longitude': -74.00961},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 258,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71822,
#   'longitude': -73.99123},
#  {'name': "Angelo's Coal Oven Pizzeria",
#   'review_count': 1014,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76492,
#   'longitude': -73.97794},
#  {'name': 'Don Antonio',
#   'review_count': 1565,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.762711,
#   'longitude': -73.986708},
#  {'name': 'Don Angie',
#   'review_count': 550,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73778,
#   'longitude': -74.00197},
#  {'name': 'Sauce',
#   'review_count': 891,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7204716,
#   'longitude': -73.9893263},
#  {'name': 'La Lanterna Di Vittorio',
#   'review_count': 1584,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73069,
#   'longitude': -74.00015},
#  {'name': 'Table 87 - Brooklyn Heights',
#   'review_count': 325,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.691219329834,
#   'longitude': -73.9973449707031},
#  {'name': "Carmine's Pizzeria",
#   'review_count': 498,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.714987,
#   'longitude': -73.94414},
#  {'name': 'Sotto Le Stelle',
#   'review_count': 324,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.743656,
#   'longitude': -73.9201782},
#  {'name': 'Sotto 13',
#   'review_count': 1008,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7372,
#   'longitude': -73.99919},
#  {'name': 'Leuca',
#   'review_count': 385,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.722121,
#   'longitude': -73.956678},
#  {'name': 'Fascati Pizza',
#   'review_count': 255,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6985,
#   'longitude': -73.99273},
#  {'name': 'Champion Pizza',
#   'review_count': 149,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.719742,
#   'longitude': -73.9872791},
#  {'name': 'Patzeria Perfect Pizza',
#   'review_count': 1727,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.759494511551836,
#   'longitude': -73.98673451962638},
#  {'name': "Cecconi's Dumbo",
#   'review_count': 958,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.7033063330116,
#   'longitude': -73.9916549604523},
#  {'name': 'Enzo Bruni Pizza Gourmet',
#   'review_count': 86,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.783433,
#   'longitude': -73.947932},
#  {'name': 'Double Zero',
#   'review_count': 586,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7261288,
#   'longitude': -73.9896645},
#  {'name': '&pizza - Wall St',
#   'review_count': 134,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7057647,
#   'longitude': -74.0085474},
#  {'name': "Roberta's Pizza",
#   'review_count': 239,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754393,
#   'longitude': -73.976103},
#  {'name': "Screamer's Pizzeria",
#   'review_count': 418,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7235518,
#   'longitude': -73.95065},
#  {'name': 'Emmy Squared Pizza - Brooklyn',
#   'review_count': 725,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.712168,
#   'longitude': -73.955707},
#  {'name': 'Milkflower',
#   'review_count': 727,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7628961,
#   'longitude': -73.9207081},
#  {'name': "Grimaldi's",
#   'review_count': 797,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7412157,
#   'longitude': -73.9938935},
#  {'name': 'PizzArte',
#   'review_count': 1200,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7629335072372,
#   'longitude': -73.9776668697596},
#  {'name': 'VEZZO NYCThinCrust Pizza',
#   'review_count': 1349,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.744435447210506,
#   'longitude': -73.9814189},
#  {'name': 'Ogliastro',
#   'review_count': 206,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.674397,
#   'longitude': -73.963448},
#  {'name': "Rosa's Pizza",
#   'review_count': 426,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.72697,
#   'longitude': -73.89564},
#  {'name': 'Neapolitan Express',
#   'review_count': 6,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77991,
#   'longitude': -73.9818},
#  {'name': 'San Marino Ristorante',
#   'review_count': 186,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72697,
#   'longitude': -74.00611},
#  {'name': 'La Bellezza',
#   'review_count': 286,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7557792663574,
#   'longitude': -73.9720153808594},
#  {'name': 'Union Pizza Works',
#   'review_count': 277,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7073067,
#   'longitude': -73.922154},
#  {'name': "Armando's Pizza",
#   'review_count': 69,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6835403,
#   'longitude': -73.9111862},
#  {'name': 'Ci Siamo',
#   'review_count': 143,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.75240549384363,
#   'longitude': -73.9982864846782},
#  {'name': 'Piacere',
#   'review_count': 692,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7196979,
#   'longitude': -73.9951175},
#  {'name': "Tony's Pizzeria & Restaurant",
#   'review_count': 345,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.699286,
#   'longitude': -73.918724},
#  {'name': 'Little Italy Pizza',
#   'review_count': 561,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.756482,
#   'longitude': -73.981484},
#  {'name': "Peppino's Brick Oven Pizza & Restaurant",
#   'review_count': 476,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.668221,
#   'longitude': -73.986936},
#  {'name': "Vic's",
#   'review_count': 534,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72693,
#   'longitude': -73.99319},
#  {'name': "Denino's Pizzeria & Tavern",
#   'review_count': 836,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6302266718896,
#   'longitude': -74.1402754933448},
#  {'name': 'Luzzos La Pizza Napoletana',
#   'review_count': 1073,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.721836749997586,
#   'longitude': -73.98329136062472},
#  {'name': 'Levante',
#   'review_count': 300,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74764,
#   'longitude': -73.94173},
#  {'name': 'Razza Pizza Artigianale',
#   'review_count': 1074,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7177490485075,
#   'longitude': -74.0441924355125},
#  {'name': 'Best Pizza',
#   'review_count': 673,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7156,
#   'longitude': -73.95352},
#  {'name': "Louie & Ernie's Pizza",
#   'review_count': 346,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.838288,
#   'longitude': -73.828563},
#  {'name': 'Garlic New York Pizza Bar',
#   'review_count': 471,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74516465585421,
#   'longitude': -73.975869},
#  {'name': 'San Matteo Pizzeria e Cucina',
#   'review_count': 364,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7746799,
#   'longitude': -73.95443},
#  {'name': 'Adoro Lei',
#   'review_count': 345,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.725612,
#   'longitude': -74.007916},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 1653,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283},
#  {'name': 'TAPPO NYCThinCrust Pizza',
#   'review_count': 546,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74337,
#   'longitude': -73.99153},
#  {'name': 'Tavola',
#   'review_count': 1145,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.755403,
#   'longitude': -73.994516},
#  {'name': 'Kesté Pizza & Vino',
#   'review_count': 1518,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7093947,
#   'longitude': -74.0048977},
#  {'name': "Luzzo's BK",
#   'review_count': 207,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.690706,
#   'longitude': -73.9952269},
#  {'name': 'Inatteso Pizzabar',
#   'review_count': 335,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7056571,
#   'longitude': -74.0172056},
#  {'name': 'Follia',
#   'review_count': 257,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7349243164062,
#   'longitude': -73.9855880737305},
#  {'name': 'Fumo',
#   'review_count': 173,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80284,
#   'longitude': -73.968119},
#  {'name': 'Celeste Restaurant',
#   'review_count': 951,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.78666,
#   'longitude': -73.97599},
#  {'name': 'Two Boots East Village',
#   'review_count': 402,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.723658440431656,
#   'longitude': -73.98503439649534},
#  {'name': 'Corner Slice',
#   'review_count': 142,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7623377,
#   'longitude': -73.9967579},
#  {'name': 'The 3 Luigis',
#   'review_count': 96,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6882597,
#   'longitude': -73.9626018},
#  {'name': 'Sauce & Barrel',
#   'review_count': 522,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.707999,
#   'longitude': -74.0142651},
#  {'name': "Rizzo's Fine Pizza",
#   'review_count': 639,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.76335,
#   'longitude': -73.91516},
#  {'name': 'Williamsburg Pizza',
#   'review_count': 348,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7078768,
#   'longitude': -73.9507711},
#  {'name': "Patsy's Pizzeria",
#   'review_count': 293,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.750427,
#   'longitude': -73.972129},
#  {'name': 'Roebling Pizza',
#   'review_count': 132,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7084890714263,
#   'longitude': -73.9610940711639},
#  {'name': 'BRADO NYCThinCrust Pizza',
#   'review_count': 155,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6905570310882,
#   'longitude': -73.99494681265617},
#  {'name': 'Stage Door Pizzeria',
#   'review_count': 272,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.712121,
#   'longitude': -74.009704},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 419,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6810107667113,
#   'longitude': -73.9771813899279},
#  {'name': 'Rosario Pizza',
#   'review_count': 21,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.69408,
#   'longitude': -73.918556},
#  {'name': 'Biga Bite',
#   'review_count': 146,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72123,
#   'longitude': -73.98408},
#  {'name': 'Keste Wall Street',
#   'review_count': 238,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70907785865903,
#   'longitude': -74.00453980520689},
#  {'name': 'Circa Brewing',
#   'review_count': 384,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.69165,
#   'longitude': -73.98603},
#  {'name': 'Solo Pizza',
#   'review_count': 199,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7223854064941,
#   'longitude': -73.98291015625},
#  {'name': 'Malaparte',
#   'review_count': 376,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73687,
#   'longitude': -74.00812},
#  {'name': 'Peperino NYC Pizza',
#   'review_count': 90,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.77275912931571,
#   'longitude': -73.99077586611165},
#  {'name': "J's Pizza",
#   'review_count': 140,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7398164,
#   'longitude': -73.9989453},
#  {'name': '2 Bros Pizza',
#   'review_count': 436,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75678,
#   'longitude': -73.98022},
#  {'name': 'La Villa',
#   'review_count': 563,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6743319055498,
#   'longitude': -73.9816949398812},
#  {'name': "Dani's House of Pizza",
#   'review_count': 1114,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7090018174257,
#   'longitude': -73.830498211479},
#  {'name': "Rosario's",
#   'review_count': 176,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77489721657789,
#   'longitude': -73.91191391165746},
#  {'name': 'Two Boots Pizza - West Village',
#   'review_count': 46,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.73308,
#   'longitude': -74.00277},
#  {'name': 'Anna Maria Pizza',
#   'review_count': 383,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7179537220535,
#   'longitude': -73.9574498958145},
#  {'name': 'Anytime Kitchen ',
#   'review_count': 2197,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.74776270790539,
#   'longitude': -73.9867793576711},
#  {'name': 'Emporio',
#   'review_count': 841,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.722647,
#   'longitude': -73.995246},
#  {'name': "Not Ray's Pizza",
#   'review_count': 240,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.68598633824293,
#   'longitude': -73.9740807999429},
#  {'name': 'Village Pizza',
#   'review_count': 145,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73927,
#   'longitude': -74.00321},
#  {'name': 'sLICe LIC',
#   'review_count': 431,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74367,
#   'longitude': -73.95345},
#  {'name': 'Proto’s Pizza',
#   'review_count': 111,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.725353,
#   'longitude': -73.989746},
#  {'name': "Patrizia's - Williamsburg",
#   'review_count': 754,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7109154314181,
#   'longitude': -73.9673637711639},
#  {'name': 'Carbone',
#   'review_count': 1448,
#   'rating': 4.0,
#   'price': '$$$$',
#   'latitude': 40.728,
#   'longitude': -74.0001497},
#  {'name': 'Milano Pizzeria',
#   'review_count': 35,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.796886,
#   'longitude': -73.93824},
#  {'name': 'House of Pizza & Calzones',
#   'review_count': 165,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.683944,
#   'longitude': -74.00225},
#  {'name': 'Oregano',
#   'review_count': 465,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7190165,
#   'longitude': -73.9586248},
#  {'name': 'Singas Famous Pizza',
#   'review_count': 93,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.71087,
#   'longitude': -73.95069},
#  {'name': 'OddFellows Ice Cream Co.',
#   'review_count': 118,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70325596349647,
#   'longitude': -73.9924016193591},
#  {'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 646,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73483,
#   'longitude': -73.98282},
#  {'name': "Beebe's",
#   'review_count': 160,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754827,
#   'longitude': -73.935918},
#  {'name': 'Osteria Brooklyn',
#   'review_count': 123,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.693154,
#   'longitude': -73.967177},
#  {'name': "Alphonso's Pizzeria & Trattoria",
#   'review_count': 144,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7143,
#   'longitude': -73.98172},
#  {'name': 'Carranza Pizza',
#   'review_count': 9,
#   'rating': 2.5,
#   'price': '$',
#   'latitude': 40.669342,
#   'longitude': -73.896667},
#  {'name': "Freddie & Pepper's",
#   'review_count': 505,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.779999,
#   'longitude': -73.980301},
#  {'name': 'Love & Dough',
#   'review_count': 232,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.702950557308085,
#   'longitude': -73.98748593042708},
#  {'name': 'Santa Panza',
#   'review_count': 207,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6947,
#   'longitude': -73.93068},
#  {'name': 'Pizzette',
#   'review_count': 55,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70858,
#   'longitude': -73.94357},
#  {'name': "Saluggi's",
#   'review_count': 582,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.720131370119134,
#   'longitude': -74.00362290743904},
#  {'name': 'Piccolo Trattoria',
#   'review_count': 106,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7591676767848,
#   'longitude': -73.9525466887989},
#  {'name': "Mark's Red Hook Pizza",
#   'review_count': 75,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6788288,
#   'longitude': -74.0113214},
#  {'name': 'Little Italy Pizza',
#   'review_count': 150,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7081041823001,
#   'longitude': -74.0046897976739},
#  {'name': "Scott's Pizza Tours",
#   'review_count': 348,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.750244140625,
#   'longitude': -73.9970245361328},
#  {'name': "Rosa's Pizza",
#   'review_count': 293,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.712192,
#   'longitude': -73.899997},
#  {'name': 'Gnocco',
#   'review_count': 539,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72713,
#   'longitude': -73.9802799},
#  {'name': "Carmine's Italian Restaurant - Times Square",
#   'review_count': 4128,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75749848725768,
#   'longitude': -73.98665333142026},
#  {'name': 'Numero 28 Pizzeria Napoletana',
#   'review_count': 556,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73041,
#   'longitude': -73.98595},
#  {'name': "Manetta's Ristorante",
#   'review_count': 426,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7427,
#   'longitude': -73.95184},
#  {'name': "Totonno's",
#   'review_count': 821,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.578913225666966,
#   'longitude': -73.98383392883555},
#  {'name': 'San Marzano Pasta Fresca',
#   'review_count': 1402,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727966,
#   'longitude': -73.988382},
#  {'name': 'New York Pizza',
#   'review_count': 130,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 31.086427,
#   'longitude': -97.753939},
#  {'name': "Roey's",
#   'review_count': 141,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73596,
#   'longitude': -74.00093},
#  {'name': 'Table 87 - Gowanus',
#   'review_count': 394,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.670664,
#   'longitude': -73.991371},
#  {'name': 'Spunto',
#   'review_count': 457,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7297584,
#   'longitude': -74.0046303},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 72,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7204894,
#   'longitude': -73.98927},
#  {'name': 'Panzerotti Bites',
#   'review_count': 156,
#   'rating': 5.0,
#   'price': '$$',
#   'latitude': 40.683715,
#   'longitude': -73.99227},
#  {'name': 'Da Gennaro',
#   'review_count': 1162,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.71832,
#   'longitude': -73.99794},
#  {'name': 'Zia Maria - Chelsea',
#   'review_count': 291,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7454863,
#   'longitude': -73.9993392},
#  {'name': "Danny's Pizzeria & Cafe",
#   'review_count': 186,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.70787,
#   'longitude': -73.93971},
#  {'name': 'San Matteo Pizza and Espresso Bar',
#   'review_count': 543,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7804,
#   'longitude': -73.95012},
#  {'name': 'Quality Italian',
#   'review_count': 1253,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7644044527436,
#   'longitude': -73.9767805051616},
#  {'name': "Emmett's",
#   'review_count': 572,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727303,
#   'longitude': -74.00243},
#  {'name': 'Tino’s Artisan Pizza',
#   'review_count': 89,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.71416668884163,
#   'longitude': -74.03979259017832},
#  {'name': "Frank's Trattoria",
#   'review_count': 163,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.73612,
#   'longitude': -73.979473},
#  {'name': "Famous Ben's Pizza",
#   'review_count': 373,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.7249388,
#   'longitude': -74.002451},
#  {'name': 'Centro Pizza Bar & Italian Kitchen',
#   'review_count': 186,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.74494463643489,
#   'longitude': -73.95312334111576},
#  {'name': 'Margherita NYC',
#   'review_count': 306,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7189865112305,
#   'longitude': -73.9969329833984},
#  {'name': 'Campania Coal Fired Pizza',
#   'review_count': 628,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.6136093139648,
#   'longitude': -74.033332824707},
#  {'name': 'Via Caramico',
#   'review_count': 29,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7517417637889,
#   'longitude': -73.9307737084595},
#  {'name': 'Broadway Pizzeria',
#   'review_count': 125,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6933151509676,
#   'longitude': -73.9290830120444},
#  {'name': 'Zero Otto Nove',
#   'review_count': 508,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7407551035259,
#   'longitude': -73.9914887388588},
#  {'name': 'Locanda Verde',
#   'review_count': 1763,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7198601300801,
#   'longitude': -74.010039072422},
#  {'name': "Tony's Di Napoli",
#   'review_count': 786,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76441,
#   'longitude': -73.96427},
#  {'name': 'Frankies 457 Spuntino',
#   'review_count': 866,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.677328,
#   'longitude': -73.997972},
#  {'name': "L'Artusi",
#   'review_count': 2096,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73372,
#   'longitude': -74.00513},
#  {'name': 'La Nostra Pizzeria',
#   'review_count': 93,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.79316,
#   'longitude': -73.94018},
#  {'name': "Joe & Sal's Pizza",
#   'review_count': 176,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.669299,
#   'longitude': -73.958753},
#  {'name': "Gino's Cucina & Brick Oven Pizza",
#   'review_count': 66,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.675178,
#   'longitude': -73.96308},
#  {'name': 'Brooklyn Pizza Market',
#   'review_count': 113,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68273,
#   'longitude': -73.99305},
#  {'name': 'Nonnas 1977',
#   'review_count': 159,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76851,
#   'longitude': -73.90997},
#  {'name': 'La Vera Pizzeria',
#   'review_count': 62,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.74067,
#   'longitude': -73.98218},
#  {'name': 'Moustache',
#   'review_count': 393,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7323545516408,
#   'longitude': -74.0052938207627},
#  {'name': 'Wheated',
#   'review_count': 355,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6465968960541,
#   'longitude': -73.9704950265688},
#  {'name': "Waldy's Wood Fired Pizza & Penne",
#   'review_count': 845,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7457666039821,
#   'longitude': -73.9906402533629},
#  {'name': 'Delmar Pizzeria',
#   'review_count': 240,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.58615,
#   'longitude': -73.95235},
#  {'name': 'Slice Pizza',
#   'review_count': 52,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.75202,
#   'longitude': -73.97376},
#  {'name': "Lena's Italian Kitchen",
#   'review_count': 298,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.742664,
#   'longitude': -73.977783},
#  {'name': 'Previti Pizza',
#   'review_count': 435,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7509380299598,
#   'longitude': -73.9767879766344},
#  {'name': 'Eataly NYC Flatiron',
#   'review_count': 5881,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74200824886595,
#   'longitude': -73.98993910744127},
#  {'name': 'Sauce Pizzeria',
#   'review_count': 244,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73033,
#   'longitude': -73.98403},
#  {'name': "Rao's",
#   'review_count': 200,
#   'rating': 4.5,
#   'price': '$$$$',
#   'latitude': 40.79392,
#   'longitude': -73.93427},
#  {'name': "Luna's Pizzeria & Restaurant",
#   'review_count': 8,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7603635173753,
#   'longitude': -74.0371671497532},
#  {'name': "Sal & Carmine's Pizza",
#   'review_count': 382,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7983115,
#   'longitude': -73.9694405},
#  {'name': 'Osteria Morini',
#   'review_count': 1240,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7219179851303,
#   'longitude': -73.9976472073402},
#  {'name': 'J & V Pizzeria',
#   'review_count': 261,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6199507795829,
#   'longitude': -73.9896828},
#  {'name': 'Highline Pizzeria',
#   'review_count': 166,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.751049,
#   'longitude': -74.0020523},
#  {'name': 'Motorino Pizzeria Napoletana',
#   'review_count': 259,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7104799,
#   'longitude': -73.96351},
#  {'name': 'Sacco Pizza',
#   'review_count': 429,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7662658691406,
#   'longitude': -73.9872665405273},
#  {'name': 'Bklyn Pizza',
#   'review_count': 164,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68903,
#   'longitude': -73.92408},
#  {'name': "Ganni's Pizza",
#   'review_count': 112,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.69419,
#   'longitude': -73.957809},
#  {'name': 'Frank Pepe Pizzeria Napoletana',
#   'review_count': 702,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.9647045,
#   'longitude': -73.8391204},
#  {'name': 'Il Corallo Trattoria',
#   'review_count': 1086,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7262073,
#   'longitude': -74.0018919},
#  {'name': "Luke's Lobster Brooklyn Bridge Park",
#   'review_count': 382,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70359,
#   'longitude': -73.99411},
#  {'name': 'Little Italy Pizza',
#   'review_count': 313,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7918751922647,
#   'longitude': -73.9735541478506},
#  {'name': 'Altesi Downtown',
#   'review_count': 109,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72511,
#   'longitude': -74.00333},
#  {'name': 'Pazza Notte',
#   'review_count': 949,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7635099,
#   'longitude': -73.978},
#  {'name': 'Bobwhite Counter',
#   'review_count': 865,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.72365,
#   'longitude': -73.97899},
#  {'name': 'Donna Margherita',
#   'review_count': 147,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76652,
#   'longitude': -73.9598},
#  {'name': 'Gotham Pizza',
#   'review_count': 175,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74381,
#   'longitude': -74.00295},
#  {'name': 'Loring Place',
#   'review_count': 499,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.73293764919451,
#   'longitude': -73.99758608256435},
#  {'name': "Libretto's Pizzeria",
#   'review_count': 211,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.74727,
#   'longitude': -73.97721},
#  {'name': 'Delizia 73',
#   'review_count': 301,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.768589,
#   'longitude': -73.955047},
#  {'name': 'Jumbo Pizza Coffee Shop',
#   'review_count': 85,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.8280452239988,
#   'longitude': -73.9489363226845},
#  {'name': "Paul's On Times Square",
#   'review_count': 326,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75522,
#   'longitude': -73.98539},
#  {'name': "Ovest Pizzoteca by Luzzo's",
#   'review_count': 574,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7507476806641,
#   'longitude': -74.0030212402344},
#  {'name': 'Trapizzino',
#   'review_count': 265,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72043,
#   'longitude': -73.98894},
#  {'name': 'Koronet Pizza',
#   'review_count': 661,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.8044212,
#   'longitude': -73.96610978649716},
#  {'name': 'Cuts & Slices',
#   'review_count': 195,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6854737,
#   'longitude': -73.9203186},
#  {'name': 'Lunetta Pizza & Restaurant',
#   'review_count': 167,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.736942,
#   'longitude': -73.984176},
#  {'name': 'Dough Vale',
#   'review_count': 95,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.70933,
#   'longitude': -73.95407},
#  {'name': 'Lucia Pizza',
#   'review_count': 600,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.76032,
#   'longitude': -73.82813},
#  {'name': 'Piccola Strada',
#   'review_count': 210,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.72662,
#   'longitude': -73.99019},
#  {'name': "Salvo's Pizzabar",
#   'review_count': 327,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7708511352539,
#   'longitude': -73.950927734375},
#  {'name': 'Rivoli Pizza',
#   'review_count': 24,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73599262334309,
#   'longitude': -74.00170597969833},
#  {'name': "Vito's Slices and Ices",
#   'review_count': 209,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7545,
#   'longitude': -73.99528},
#  {'name': 'Non Solo Piada',
#   'review_count': 383,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.75414,
#   'longitude': -73.99245},
#  {'name': "Percy's Pizza",
#   'review_count': 247,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.729076,
#   'longitude': -74.001534},
#  {'name': 'Uva',
#   'review_count': 2601,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.7722,
#   'longitude': -73.95566},
#  {'name': 'Pranzo Pizza & Pasta',
#   'review_count': 109,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7036301,
#   'longitude': -74.0101127},
#  {'name': 'Swift',
#   'review_count': 364,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.727309,
#   'longitude': -73.992387},
#  {'name': "Denino's Greenwich Village",
#   'review_count': 245,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7294,
#   'longitude': -74.00111},
#  {'name': 'Sunnyside Pizza',
#   'review_count': 444,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7438380472824,
#   'longitude': -73.9241266284942},
#  {'name': "Napoli's Pizza",
#   'review_count': 175,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73937,
#   'longitude': -74.03483},
#  {'name': 'Gran Morsi',
#   'review_count': 438,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.7142052394856,
#   'longitude': -74.0077535494539},
#  {'name': 'Patsy’s Pizzeria',
#   'review_count': 440,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.76177,
#   'longitude': -73.96575},
#  {'name': 'Mama Mia 44 SW',
#   'review_count': 764,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.759761,
#   'longitude': -73.992065},
#  {'name': 'Kiss My Slice',
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.75576,
#   'longitude': -73.99052},
#  {'name': 'Casa Theodoro',
#   'review_count': 129,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75693,
#   'longitude': -73.906747},
#  {'name': '99 Cent Fresh Pizza',
#   'review_count': 52,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7264595,
#   'longitude': -73.9895782},
#  {'name': "Renato's Pizza Masters",
#   'review_count': 444,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7442813,
#   'longitude': -74.0503861},
#  {'name': 'La Mia Pizza',
#   'review_count': 24,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.73311,
#   'longitude': -73.99011},
#  {'name': 'The Grotto Pizzeria & Ristorante',
#   'review_count': 164,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70574,
#   'longitude': -74.012402},
#  {'name': '2 Bros Pizza',
#   'review_count': 617,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.72866,
#   'longitude': -73.988487},
#  {'name': 'Liberty Pizzeria',
#   'review_count': 38,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.693225,
#   'longitude': -73.966018},
#  {'name': 'La Pecora Bianca',
#   'review_count': 894,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.74358,
#   'longitude': -73.9892},
#  {'name': "Jeannie's",
#   'review_count': 20,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7662427,
#   'longitude': -73.98124349999999},
#  {'name': "Artichoke Basille's Pizza",
#   'review_count': 279,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.70638449968762,
#   'longitude': -73.92288771165168},
#  {'name': "Angelo's Pizza",
#   'review_count': 620,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7638169909039,
#   'longitude': -73.9827420901337},
#  {'name': "Nick's Pizza - Forest Hills",
#   'review_count': 914,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71797254115706,
#   'longitude': -73.84048067055303},
#  {'name': 'Numero 28 Pizzeria - West Village',
#   'review_count': 493,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73012,
#   'longitude': -74.00275},
#  {'name': 'Fornino- Greenpoint',
#   'review_count': 243,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.728949,
#   'longitude': -73.953999},
#  {'name': "Gnoccheria By Luzzo's",
#   'review_count': 488,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.723315,
#   'longitude': -73.983139},
#  {'name': 'ZuriLee Restaurant',
#   'review_count': 306,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.654521,
#   'longitude': -73.959443},
#  {'name': "Antonio's Pizzeria & Restaurant",
#   'review_count': 250,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6914284,
#   'longitude': -73.9824964},
#  {'name': "Rosella's Pizzeria",
#   'review_count': 254,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.710117,
#   'longitude': -74.005661},
#  {'name': "Nino's 46",
#   'review_count': 1268,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7569046125342,
#   'longitude': -73.980516},
#  {'name': 'Babbo',
#   'review_count': 2524,
#   'rating': 4.0,
#   'price': '$$$$',
#   'latitude': 40.732283,
#   'longitude': -73.999284},
#  {'name': 'Upside Pizza',
#   'review_count': 192,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7550912,
#   'longitude': -73.9911494},
#  {'name': 'Tonys Pizzeria',
#   'review_count': 14,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.68198,
#   'longitude': -73.87888},
#  {'name': "Nick's Pizza",
#   'review_count': 570,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78272735790179,
#   'longitude': -73.9478073},
#  {'name': 'Malatesta Trattoria',
#   'review_count': 1308,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73285,
#   'longitude': -74.00847},
#  {'name': 'Coletta',
#   'review_count': 80,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.74094,
#   'longitude': -73.98139},
#  {'name': 'Pizza By Certé',
#   'review_count': 455,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7619979368852,
#   'longitude': -73.9761684},
#  {'name': "John's of Times Square",
#   'review_count': 2266,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.75823,
#   'longitude': -73.98836},
#  {'name': 'Pizza Secret',
#   'review_count': 210,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6808,
#   'longitude': -73.97764},
#  {'name': 'Obicà Mozzarella Bar Pizza e Cucina',
#   'review_count': 486,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7400486,
#   'longitude': -73.9893018},
#  {'name': 'Champion Pizza',
#   'review_count': 86,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.73592407559118,
#   'longitude': -73.99391475241151},
#  {'name': 'Babbalucci',
#   'review_count': 447,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.80894,
#   'longitude': -73.94496},
#  {'name': "Dado's Pizza",
#   'review_count': 22,
#   'rating': 5.0,
#   'price': '$',
#   'latitude': 40.81228,
#   'longitude': -73.95149},
#  {'name': 'Osteria Cotta',
#   'review_count': 1003,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78554,
#   'longitude': -73.97263},
#  {'name': 'Emmy Squared Pizza - Upper East Side',
#   'review_count': 221,
#   'rating': 4.0,
# ...
#   'review_count': 41,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.646676,
#   'longitude': -73.883467},
#  {'name': 'La Bella Mariella Pizzeria',
#   'review_count': 59,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.715406,
#   'longitude': -73.901038},
#  {'name': 'Lenny and Johns Pizzeria',
#   'review_count': 238,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.6199963,
#   'longitude': -73.9342463},
#  {'name': 'Jardino Restaurant',
#   'review_count': 142,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.76686,
#   'longitude': -73.96249},
#  {'name': "G&J's Pizzeria",
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7903349463747,
#   'longitude': -73.946079551947},
#  {'name': "Gino's Restaurant",
#   'review_count': 759,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.63,
#   'longitude': -74.02274},
#  {'name': 'DOUGH By Licastri',
#   'review_count': 198,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.59391,
#   'longitude': -74.09948},
#  {'name': 'The Smith',
#   'review_count': 1936,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7716201269986,
#   'longitude': -73.9818377981476},
#  {'name': "Nonna Delia's",
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.78224,
#   'longitude': -73.84619},
#  {'name': "Mimi's Italian Restaurant & Piano Bar",
#   'review_count': 346,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.75611,
#   'longitude': -73.96728},
#  {'name': "Carlo's Pizza",
#   'review_count': 173,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.71259,
#   'longitude': -73.8781},
#  {'name': 'Barosa',
#   'review_count': 394,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.726197,
#   'longitude': -73.869795},
#  {'name': 'Family Pizza',
#   'review_count': 64,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.65585,
#   'longitude': -73.96008},
#  {'name': "Giovanni's Pizza Restaurant",
#   'review_count': 22,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.741315,
#   'longitude': -73.917955},
#  {'name': 'Angeletto Restaurant',
#   'review_count': 273,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.753188,
#   'longitude': -73.969365},
#  {'name': 'Trattoria Napoli',
#   'review_count': 148,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.77794,
#   'longitude': -74.01825},
#  {'name': 'Ungaro Coal Fired Pizza Cafe',
#   'review_count': 42,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.62624,
#   'longitude': -74.13315},
#  {'name': 'Pizza Wagon',
#   'review_count': 283,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.62129,
#   'longitude': -74.02659},
#  {'name': "John & Joe's Pizzeria",
#   'review_count': 189,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8545949,
#   'longitude': -73.86578},
#  {'name': 'Piatto',
#   'review_count': 218,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7435117,
#   'longitude': -73.9590968},
#  {'name': 'Houdini Pizza Laboratory',
#   'review_count': 166,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6358753412935,
#   'longitude': -74.3918408453465},
#  {'name': 'Franklin Pizza',
#   'review_count': 58,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.729684,
#   'longitude': -73.957827},
#  {'name': 'La Guardiola Pizzeria',
#   'review_count': 82,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67537,
#   'longitude': -74.10894},
#  {'name': 'Da Marino',
#   'review_count': 607,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.76102,
#   'longitude': -73.98526},
#  {'name': 'Avena Downtown',
#   'review_count': 104,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.7289,
#   'longitude': -74.00216},
#  {'name': "Basile's Pizza",
#   'review_count': 309,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.736978968163,
#   'longitude': -74.030820734929},
#  {'name': 'Fire & Oak - Jersey City',
#   'review_count': 832,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.72494,
#   'longitude': -74.03631},
#  {'name': 'Parm',
#   'review_count': 828,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72303,
#   'longitude': -73.99567},
#  {'name': 'Houdini Pizza Laboratory',
#   'review_count': 166,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6358753412935,
#   'longitude': -74.3918408453465},
#  {'name': 'Franklin Pizza',
#   'review_count': 58,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.729684,
#   'longitude': -73.957827},
#  {'name': 'La Guardiola Pizzeria',
#   'review_count': 82,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.67537,
#   'longitude': -74.10894},
#  {'name': 'Da Marino',
#   'review_count': 607,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.76102,
#   'longitude': -73.98526},
#  {'name': 'Avena Downtown',
#   'review_count': 104,
#   'rating': 4.5,
#   'price': '$$$',
#   'latitude': 40.7289,
#   'longitude': -74.00216},
#  {'name': "Basile's Pizza",
#   'review_count': 309,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.736978968163,
#   'longitude': -74.030820734929},
#  {'name': 'Fire & Oak - Jersey City',
#   'review_count': 832,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.72494,
#   'longitude': -74.03631},
#  {'name': 'Cafe Fiorello',
#   'review_count': 864,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.77134,
#   'longitude': -73.9819051},
#  {'name': 'Parm',
#   'review_count': 828,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72303,
#   'longitude': -73.99567},
#  {'name': 'La Masseria',
#   'review_count': 649,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.760868632784,
#   'longitude': -73.986348802868},
#  {'name': 'Black Tap - Midtown',
#   'review_count': 1320,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76354770917096,
#   'longitude': -73.9797715},
#  {'name': 'Pizzeria Las Americas',
#   'review_count': 48,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.7166,
#   'longitude': -74.03899},
#  {'name': "Sammy Sam's Pizzeria",
#   'review_count': 13,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7944610511506,
#   'longitude': -74.0122780948877},
#  {'name': "Broadway Joe's Pizza",
#   'review_count': 69,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.8899,
#   'longitude': -73.89846},
#  {'name': "Peppino's Brick Oven Pizza & Restaurant",
#   'review_count': 247,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.62984,
#   'longitude': -74.02862},
#  {'name': 'Cookshop',
#   'review_count': 2241,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.745731881448236,
#   'longitude': -74.00540454907613},
#  {'name': "Sabrina's Pizzeria & Restaurant",
#   'review_count': 33,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.708374,
#   'longitude': -73.958327},
#  {'name': "Shelsky's of Brooklyn Appetizing & Delicateseen",
#   'review_count': 230,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.689386,
#   'longitude': -73.9922942},
#  {'name': '3 Giovani',
#   'review_count': 177,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.72907,
#   'longitude': -73.99839},
#  {'name': 'Wo Hop',
#   'review_count': 1580,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7142239034582,
#   'longitude': -73.9988691693115},
#  {'name': 'Carlos Pizza',
#   'review_count': 47,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7045665,
#   'longitude': -73.9103926},
#  {'name': "Original Napoli's Pizza",
#   'review_count': 47,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.673224,
#   'longitude': -73.869757},
#  {'name': 'Celestine',
#   'review_count': 260,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.704676,
#   'longitude': -73.987975},
#  {'name': 'Parm - New York',
#   'review_count': 650,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7764333,
#   'longitude': -73.9794019},
#  {'name': 'Blaze Pizza',
#   'review_count': 233,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.738388,
#   'longitude': -74.1708115},
#  {'name': 'Urban Tomato',
#   'review_count': 150,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.8413615968694,
#   'longitude': -73.9884319304327},
#  {'name': 'Da Raffaele',
#   'review_count': 203,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.7535386913133,
#   'longitude': -73.9666010811925},
#  {'name': 'Pizza Classica',
#   'review_count': 467,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.706858,
#   'longitude': -73.855654},
#  {'name': 'Battle Hill Tavern',
#   'review_count': 49,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.66023,
#   'longitude': -73.99135},
#  {'name': "Tony's Pizzeria",
#   'review_count': 115,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.6192460894272,
#   'longitude': -74.0088415145874},
#  {'name': 'Serafina Fabulous Pizza',
#   'review_count': 384,
#   'rating': 3.0,
#   'price': '$$',
#   'latitude': 40.7762350782493,
#   'longitude': -73.9623423504256},
#  {'name': 'Broadstone Bar & Kitchen',
#   'review_count': 319,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.70411,
#   'longitude': -74.01186},
#  {'name': 'The Elgin',
#   'review_count': 196,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.758194,
#   'longitude': -73.980905},
#  {'name': "Roman's",
#   'review_count': 251,
#   'rating': 3.5,
#   'price': '$$$',
#   'latitude': 40.689671,
#   'longitude': -73.96953},
#  {'name': 'Casa Nonna',
#   'review_count': 554,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.75496,
#   'longitude': -73.99247},
#  {'name': 'Supper',
#   'review_count': 1428,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.72290786539601,
#   'longitude': -73.98520720537888},
#  {'name': 'Hex & Company',
#   'review_count': 66,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.806595775543094,
#   'longitude': -73.9652416705522},
#  {'name': 'Brooklyn Pizza Crew',
#   'review_count': 165,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.67279,
#   'longitude': -73.95053},
#  {'name': 'Friendly Gourmet Pizza',
#   'review_count': 61,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.70925,
#   'longitude': -74.0088},
#  {'name': 'Pizza Bella',
#   'review_count': 24,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7429257,
#   'longitude': -73.8831808},
#  {'name': 'Bar Primi',
#   'review_count': 717,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.725639,
#   'longitude': -73.991714},
#  {'name': "Rosa's Pizza",
#   'review_count': 110,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.713317,
#   'longitude': -73.875422},
#  {'name': 'VIPizza',
#   'review_count': 326,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7612782716751,
#   'longitude': -73.7699277698994},
#  {'name': 'San Matteo Takeaway',
#   'review_count': 163,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7801684,
#   'longitude': -73.9502899},
#  {'name': 'San Matteo Takeaway',
#   'review_count': 163,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7801684,
#   'longitude': -73.9502899},
#  {'name': 'Pasta Louise Cafe',
#   'review_count': 214,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.666091,
#   'longitude': -73.9787254},
#  {'name': 'Krave It Pizza & Sandwich Joint',
#   'review_count': 735,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7637637393418,
#   'longitude': -73.7709849487713},
#  {'name': 'Lillian Pizzeria',
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7169776965988,
#   'longitude': -73.8522986602726},
#  {'name': 'Lenz Delicatessen',
#   'review_count': 38,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7334702326849,
#   'longitude': -73.9768266677856},
#  {'name': "Tony's and Orazio Pizza",
#   'review_count': 156,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.7010231018066,
#   'longitude': -73.9226455688477},
#  {'name': 'Parm - New York',
#   'review_count': 650,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7764333,
#   'longitude': -73.9794019},
#  {'name': "Empanada Mama - Hell's Kitchen",
#   'review_count': 2799,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.76441,
#   'longitude': -73.9885},
#  {'name': "Patricia's",
#   'review_count': 575,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.84912,
#   'longitude': -73.8533099},
#  {'name': 'Anella',
#   'review_count': 432,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.73327,
#   'longitude': -73.95786},
#  {'name': "Bijan's",
#   'review_count': 632,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.68803,
#   'longitude': -73.98671},
#  {'name': "Joe & Pat's Pizzeria",
#   'review_count': 441,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.61281,
#   'longitude': -74.12198},
#  {'name': 'Pi Bakerie',
#   'review_count': 314,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.723644,
#   'longitude': -74.00325},
#  {'name': 'Tony Pepperoni Pizzeria',
#   'review_count': 27,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.613404,
#   'longitude': -73.99635},
#  {'name': "Martiniello's III",
#   'review_count': 23,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.682871137684,
#   'longitude': -73.8510749861598},
#  {'name': 'The Brooklyn Firefly',
#   'review_count': 268,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.63468,
#   'longitude': -74.02631},
#  {'name': 'Manducatis',
#   'review_count': 151,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7445948529884,
#   'longitude': -73.9490695847509},
#  {'name': 'Belli Osteria',
#   'review_count': 282,
#   'rating': 4.5,
#   'price': '$$',
#   'latitude': 40.6835199838354,
#   'longitude': -73.9669024162476},
#  {'name': 'Pommes Frites',
#   'review_count': 1050,
#   'rating': 4.5,
#   'price': '$',
#   'latitude': 40.730022,
#   'longitude': -74.000152},
#  {'name': "Mekelburg's",
#   'review_count': 103,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.71375,
#   'longitude': -73.96704},
#  {'name': 'Carve',
#   'review_count': 422,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.7602042287575,
#   'longitude': -73.9873568460327},
#  {'name': "The Meatball Shop - Hell's Kitchen",
#   'review_count': 460,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.7651804928198,
#   'longitude': -73.9874866666706},
#  {'name': 'La Mia Pizza',
#   'review_count': 251,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.774822,
#   'longitude': -73.953295},
#  {'name': "Tony's Pizzeria",
#   'review_count': 6,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6373927,
#   'longitude': -73.919349},
#  {'name': 'Sunny John Pizzeria',
#   'review_count': 40,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.6190419,
#   'longitude': -73.9226648},
#  {'name': 'Pronto Pizza',
#   'review_count': 106,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.68946,
#   'longitude': -73.99233},
#  {'name': 'Soco',
#   'review_count': 2289,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.693739699999334,
#   'longitude': -73.96449631779052},
#  {'name': 'Sergimmo Salumeria',
#   'review_count': 706,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.754296,
#   'longitude': -73.995498},
#  {'name': 'Old Rose',
#   'review_count': 120,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.7383,
#   'longitude': -74.00932},
#  {'name': 'Shake Shack Dumbo',
#   'review_count': 380,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.703081726098,
#   'longitude': -73.994004},
#  {'name': 'Armonie',
#   'review_count': 116,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.799791923483,
#   'longitude': -73.942575354665},
#  {'name': 'Stella 34 Trattoria',
#   'review_count': 710,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.75049486336486,
#   'longitude': -73.98798861987918},
#  {'name': 'Singas Famous Pizza',
#   'review_count': 115,
#   'rating': 3.0,
#   'price': '$',
#   'latitude': 40.75416828100335,
#   'longitude': -73.82289803347588},
#  {'name': 'Bella Notte',
#   'review_count': 215,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.886035,
#   'longitude': -73.909539},
#  {'name': 'Minitalia Pizzeria',
#   'review_count': 49,
#   'rating': 4.0,
#   'price': '$',
#   'latitude': 40.708145443285,
#   'longitude': -73.8977218647803},
#  {'name': 'La Pizza & La Pasta at Eataly Flatiron',
#   'review_count': 440,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.742344,
#   'longitude': -73.989952},
#  {'name': 'Cozzi Pizza',
#   'review_count': 38,
#   'rating': 3.5,
#   'price': '$',
#   'latitude': 40.70377,
#   'longitude': -73.94749},
#  {'name': 'PG Pizza',
#   'review_count': 14,
#   'rating': 3.5,
#   'price': '$$',
#   'latitude': 40.8337123,
#   'longitude': -73.9153637},
#  {'name': 'Faro',
#   'review_count': 311,
#   'rating': 4.0,
#   'price': '$$$',
#   'latitude': 40.707407,
#   'longitude': -73.922839},
#  {'name': 'Mercato',
#   'review_count': 996,
#   'rating': 4.0,
#   'price': '$$',
#   'latitude': 40.75619,
#   'longitude': -73.9937}]

# %% [markdown]
# This code may take up to a few minutes to run.
#
# If you get an error trying to get the response body in JSON format, try adding `time.sleep(1)` right after the `requests.get` line, so your code will sleep for 1 second between each API call.

# %% [markdown]
# ## 3. Perform Exploratory Analysis
#
# Take the businesses from the previous question and do an initial exploratory analysis. We have provided some plots for you to interpret:

# %%
# Run this cell without changes
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(16, 5))

# Plot distribution of number of reviews
all_review_counts = [x["review_count"] for x in full_dataset]
ax1.hist(all_review_counts)
ax1.set_title("Review Count Distribution")
ax1.set_xlabel("Number of Reviews")
ax1.set_ylabel("Number of Businesses")

# Plot rating distribution
all_ratings = [x["rating"] for x in full_dataset]
rating_counter = Counter(all_ratings)
rating_keys = sorted(rating_counter.keys())
ax2.bar(rating_keys, [rating_counter[key] for key in rating_keys])
ax2.set_title("Rating Distribution")
ax2.set_xlabel("Rating")
ax2.set_ylabel("Number of Businesses")

# Plot price distribution
all_prices = [x["price"].replace("$", r"\$") for x in full_dataset]
price_counter = Counter(all_prices)
price_keys = sorted(price_counter.keys())
ax3.bar(price_keys, [price_counter[key] for key in price_keys])
ax3.set_title("Price Distribution")
ax3.set_xlabel("Price Category")
ax3.set_ylabel("Number of Businesses");

# %% [markdown]
# Describe the distributions displayed above and interpret them in the context of your query. (Your answer may differ from the solution branch depending on your query.)

# %%
# Replace None with appropriate text
"""
None
"""

# %% [markdown]
# In the cell below, we also plot the rating distributions by price. In this setup, a price of one dollar sign is "lower price" and everything else is "higher price".

# %%
# Run this cell without changes

higher_price = []
lower_price = []
for row in full_dataset:
    if row["price"] == "$":
        lower_price.append(row["rating"])
    else:
        higher_price.append(row["rating"])
        
fig, ax = plt.subplots()

ax.hist([higher_price, lower_price], label=["higher price", "lower price"], density=True)

ax.legend();

# %% [markdown]
# Is a higher price associated with a higher rating? (No need for any additional math/statistics, just interpret what you see in the plot.)

# %%
# Replace None with appropriate text
"""
"""

# %% [markdown]
# Finally, let's look at ratings vs. review counts:

# %%
# Run this cell without changes
fig, ax = plt.subplots(figsize=(16,5))

ax.scatter(all_review_counts, all_ratings, alpha=0.2)
ax.set_xlabel("Number of Reviews")
ax.set_ylabel("Rating")
# "zoom in" to a subset of review counts
ax.set_xlim(left=0, right=1000);

# %% [markdown]
# Is a higher number of reviews associated with a higher rating?

# %%
# Replace None with appropriate text
"""
None
"""

# %% [markdown]
# ## 4. Create a Folium Map
#
# Make a map using Folium of the businesses you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.
#
# You can center the map around the latitude and longitude of the first item in `full_dataset`.

# %%
# Replace None with appropriate code

# Import the library
import folium

# Set up center latitude and longitude
center_lat = full_dataset[0]['latitude']
center_long = full_dataset[0]['longitude']

# Initialize map with center lat and long
yelp_map = folium.Map([center_lat, center_long], zoom_start=13)

# Adjust this limit to see more or fewer businesses
limit=100

for business in full_dataset[:limit]:
    # Extract information about business
    lat = business['latitude']
    long = business['longitude']
    name = business['name']
    rating = business['rating']
    price = business['price']
    details = "{}\nPrice: {} Rating:{}".format(name,price,rating)
    
    # Create popup with relevant details
    popup = folium.Popup(details, parse_html=True)
    
    # Create marker with relevant lat/long and popup
    marker = folium.Marker(location=[lat,long])
    
    marker.add_to(yelp_map)
    
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f27010fa88c846a71daece419bdd7ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f27010fa88c846a71daece419bdd7ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1f27010fa88c846a71daece419bdd7ac = L.map(
#                 &quot;map_1f27010fa88c846a71daece419bdd7ac&quot;,
#                 {
#                     center: [40.72308755605564, -73.99453001177575],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9b2f01ced3a90cf045d93eaac972fc2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_6d6c1649b89bec960b856493d5402a36 = L.marker(
#                 [40.72308755605564, -73.99453001177575],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_58d118c6dc34f315a212380929af42ee = L.marker(
#                 [40.70274718768062, -73.99343490196397],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_d564fb2a9e380d64bc8036c744dd800f = L.marker(
#                 [40.7215934960083, -73.9955956044561],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_d50eb1fabc428795af4824c509453672 = L.marker(
#                 [40.71162, -73.95783],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_7cb5fd3a11a0985d39528e680583e733 = L.marker(
#                 [40.681840746711224, -74.0003327],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_b587fd1a9591b231b32292bcaec1ee8c = L.marker(
#                 [40.722766, -73.996233],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_6439ce57bd3374bd4d3e16e60428bbc5 = L.marker(
#                 [40.73060076, -74.00215997],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_b9e39cdb2237c79392d3328b58dc3b77 = L.marker(
#                 [40.7547, -73.98696],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_c87ed40a1714c17d6059986d1685dba7 = L.marker(
#                 [40.73158, -74.00332],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_dedecf3bafd959b7084204b547b82491 = L.marker(
#                 [40.70493, -73.93399],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_47549f6b90c983f35604811850cfed4b = L.marker(
#                 [40.7320627016512, -74.0036552270137],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_500f533e283333e4e29cb6355af76575 = L.marker(
#                 [40.7026459, -73.9932413],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_7df26ab68f92b3612e7c8bf43e5dd536 = L.marker(
#                 [40.73331, -73.98763],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_8c2af989fc02e7e39c68ef63d6cef0ca = L.marker(
#                 [40.729546, -73.958568],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_44a498dc06ccae6e1e25fe938fa452f0 = L.marker(
#                 [40.6897, -73.965369],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_a0556f6967eee73f9f104039d8dafe00 = L.marker(
#                 [40.71534, -73.9914],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_cce2dad169fa20b7242223bb1a32c013 = L.marker(
#                 [40.75225, -73.98061],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_0d1818ff9d988aca72a865cdcacaa9e5 = L.marker(
#                 [40.625093, -73.961531],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_7b0e45be7ee0407a335246f3d9f3f917 = L.marker(
#                 [40.69116658201196, -73.99065911521895],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_e453b1e803c525a68817167ee3e167d1 = L.marker(
#                 [40.66163, -73.99334],
#                 {}
#             ).addTo(map_1f27010fa88c846a71daece419bdd7ac);
#
#
#             var marker_bddddbc6f82cca3828489445cfe3920f = L.marker(
#                 [40.733798036104304, -73.9997

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
